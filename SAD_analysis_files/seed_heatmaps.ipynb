# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ## Pick which seed maps to use from Brainnetome atlas

# %%
#Load seed map correlation matrices for amygdala, hippocampus, parahippocampus, 
#cingulate, precentral, fusiform face area, precuneus, & insula
amyg = pd.read_table('amyg_corr.txt', delimiter='\s+', header=None)
hipp = pd.read_table('hipp_corr.txt', delimiter='\s+', header=None)
parahipp = pd.read_table('parahipp_corr.txt', delimiter='\s+', header=None)
cing = pd.read_table('cingulate_corr.txt', delimiter='\s+', header=None)
precent = pd.read_table('precentral_corr.txt', delimiter='\s+', header=None)
ffa = pd.read_table('ffa_corr.txt', delimiter='\s+', header=None)
pcc = pd.read_table('PCC_corr.txt', delimiter='\s+', header=None)
insula = pd.read_table('insula_corr.txt', delimiter='\s+', header=None)

# %%
# Generate masks for the upper triangles
mask_amyg = np.zeros_like(amyg, dtype=np.bool)
mask_amyg[np.tril_indices_from(mask_amyg)] = True

mask_hipp = np.zeros_like(hipp, dtype=np.bool)
mask_hipp[np.tril_indices_from(mask_hipp)] = True

mask_parahipp = np.zeros_like(parahipp, dtype=np.bool)
mask_parahipp[np.tril_indices_from(mask_parahipp)] = True

mask_cing = np.zeros_like(cing, dtype=np.bool)
mask_cing[np.tril_indices_from(mask_cing)] = True

mask_precent = np.zeros_like(precent, dtype=np.bool)
mask_precent[np.tril_indices_from(mask_precent)] = True

mask_ffa = np.zeros_like(ffa, dtype=np.bool)
mask_ffa[np.tril_indices_from(mask_ffa)] = True

mask_pcc = np.zeros_like(pcc, dtype=np.bool)
mask_pcc[np.tril_indices_from(mask_pcc)] = True

mask_insula = np.zeros_like(insula, dtype=np.bool)
mask_insula[np.tril_indices_from(mask_insula)] = True

# %%
# Generate a custom diverging colormap
sns.set(font_scale = 2, style="white")

# Set up the matplotlib figures
f, ax1 = plt.subplots(nrows=1,ncols=1, figsize=(25, 15), sharex=False, sharey=False)

# Draw the heatmaps
sns.heatmap(precent, mask=mask_precent, cmap=sns.color_palette("coolwarm", 20), annot=True,
            square=True, linewidths=.5, center=0, ax=ax1, fmt="0.3",
            cbar_kws={"shrink": .5},annot_kws={"size": 15, "weight":'bold'}, xticklabels=False, yticklabels=False)
plt.title('Precentral seed correlations')
plt.show()

# %%
precent.mean(axis=0)
# Out:
# 0     0.908829
# 1     0.910966
# 2     0.899821
# 3     0.904370
# 4     0.904366
# 5     0.890763
# 6     0.903444
# 7     0.894423
# 8     0.889777
# 9     0.907866
# 10    0.865842
# 11    0.879768
# dtype: float64

# %%
# Generate a custom diverging colormap
sns.set(font_scale = 2, style="white")

# Set up the matplotlib figures
f, ax1 = plt.subplots(nrows=1,ncols=1, figsize=(20, 10), sharex=False, sharey=False)

# Draw the heatmaps
sns.heatmap(ffa, mask=mask_ffa, cmap=sns.color_palette("coolwarm", 20), annot=True,
            square=True, linewidths=.5, center=0, ax=ax1, fmt="0.3",
            cbar_kws={"shrink": .5},annot_kws={"size": 15, "weight":'bold'}, xticklabels=False, yticklabels=False)
plt.title('Fusiform face area seed correlations')
plt.show()

# %%
ffa.mean(axis=0)
# Out:
# 0    0.903783
# 1    0.904990
# 2    0.911080
# 3    0.910148
# 4    0.906509
# 5    0.907077
# dtype: float64

# %%
# Generate a custom diverging colormap
sns.set(font_scale = 2, style="white")

# Set up the matplotlib figures
f, ax1 = plt.subplots(nrows=1,ncols=1, figsize=(30, 15), sharex=False, sharey=False)

# Draw the heatmaps
sns.heatmap(parahipp, mask=mask_parahipp, cmap=sns.color_palette("coolwarm", 20), annot=True,
            square=True, linewidths=.5, center=0, ax=ax1, fmt="0.3",
            cbar_kws={"shrink": .5},annot_kws={"size": 15, "weight":'bold'}, xticklabels=False, yticklabels=False)
plt.title('Parahippocampus seed correlations')
plt.show()

# %%
parahipp.mean(axis=0)
# Out:
# 0     0.859520
# 1     0.853072
# 2     0.877213
# 3     0.873172
# 4     0.861203
# 5     0.862655
# 6     0.835604
# 7     0.860756
# 8     0.857312
# 9     0.860898
# 10    0.872734
# 11    0.876251
# dtype: float64

# %%
# Generate a custom diverging colormap
sns.set(font_scale = 2, style="white")

# Set up the matplotlib figures
f, ax1 = plt.subplots(nrows=1,ncols=1, figsize=(20, 10), sharex=False, sharey=False)

# Draw the heatmaps
sns.heatmap(pcc, mask=mask_pcc, cmap=sns.color_palette("coolwarm", 20), annot=True,
            square=True, linewidths=.5, center=0, ax=ax1, fmt="0.3",
            cbar_kws={"shrink": .5},annot_kws={"size": 15, "weight":'bold'}, xticklabels=False, yticklabels=False)
plt.title('Precuneus seed correlations')
plt.show()

# %%
pcc.mean(axis=0)
# Out:
# 0    0.905744
# 1    0.910900
# 2    0.882886
# 3    0.796097
# 4    0.871565
# 5    0.851903
# 6    0.894986
# 7    0.911885
# dtype: float64

# %%
# Generate a custom diverging colormap
sns.set(font_scale = 2, style="white")

# Set up the matplotlib figures
f, ax1 = plt.subplots(nrows=1,ncols=1, figsize=(25, 15), sharex=False, sharey=False)

# Draw the heatmaps
sns.heatmap(insula, mask=mask_insula, cmap=sns.color_palette("coolwarm", 20), annot=True,
            square=True, linewidths=.5, center=0, ax=ax1, fmt="0.3",
            cbar_kws={"shrink": .5},annot_kws={"size": 15, "weight":'bold'}, xticklabels=False, yticklabels=False)
plt.title('Insula seed correlations')
plt.show()

# %%
insula.mean(axis=0)
# Out:
# 0     0.811805
# 1     0.859132
# 2     0.817674
# 3     0.846214
# 4     0.837948
# 5     0.845547
# 6     0.872285
# 7     0.878022
# 8     0.852629
# 9     0.871489
# 10    0.887847
# 11    0.885847
# dtype: float64

# %%
# Generate a custom diverging colormap
sns.set(font_scale = 2, style="white")

# Set up the matplotlib figures
f, ax1 = plt.subplots(nrows=1,ncols=1, figsize=(30, 15), sharex=False, sharey=False)

# Draw the heatmaps
sns.heatmap(cing, mask=mask_cing, cmap=sns.color_palette("coolwarm", 20), annot=True,
            square=True, linewidths=.5, center=0, ax=ax1, fmt="0.3",
            cbar_kws={"shrink": .5},annot_kws={"size": 15, "weight":'bold'}, xticklabels=False, yticklabels=False)
plt.title('Cingulate seed correlations')
plt.show()

# %%
cing.mean(axis=0)
# Out:
# 0     0.900208
# 1     0.902881
# 2     0.909485
# 3     0.889936
# 4     0.915861
# 5     0.914444
# 6     0.889744
# 7     0.881847
# 8     0.869064
# 9     0.895741
# 10    0.880270
# 11    0.851437
# 12    0.885982
# 13    0.903820
# dtype: float64

# %%
# Generate a custom diverging colormap
sns.set(font_scale = 2, style="white")

f, ax1 = plt.subplots(nrows=1,ncols=1, figsize=(10, 5), sharex=False, sharey=False)

# Draw the heatmaps
sns.heatmap(amyg, mask=mask_amyg, cmap=sns.color_palette("coolwarm", 7), annot=True,
            square=True, linewidths=.5, center=0, ax=ax1, vmin=0.7, vmax=0.8, fmt="0.3",
            cbar_kws={"shrink": .5},annot_kws={"size": 15, "weight":'bold'}, xticklabels=False, yticklabels=False)

plt.title('Amygdala seed correlations')
plt.show()

# %%
amyg.mean(axis=0)
# Out:
# 0    0.877427
# 1    0.877632
# 2    0.877500
# 3    0.877115
# dtype: float64

# %%
# Generate a custom diverging colormap
sns.set(font_scale = 2, style="white")

f, ax1 = plt.subplots(nrows=1,ncols=1, figsize=(10, 5), sharex=False, sharey=False)

# Draw the heatmaps
sns.heatmap(hipp, mask=mask_hipp, cmap=sns.color_palette("coolwarm", 7), annot=True,
            square=True, linewidths=.5, center=0, ax=ax1, vmin=0.8, vmax=0.9, fmt="0.3",
            cbar_kws={"shrink": .5},annot_kws={"size": 15, "weight":'bold'}, xticklabels=False, yticklabels=False)

plt.title('Hippocampus seed correlations')
plt.show()

# %%
hipp.mean(axis=0)
# Out:
# 0    0.907194
# 1    0.906571
# 2    0.905783
# 3    0.906828
# dtype: float64
