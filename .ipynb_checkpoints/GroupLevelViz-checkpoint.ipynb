# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from nilearn import plotting
from nilearn import datasets
from nilearn import surface
import nibabel as nib
from scipy.stats import norm
import seaborn as sns
import statsmodels

# %% [markdown]
# ## Amygdala212 significant cluster

# %%
plt.figure(figsize=(12, 10))
plotting.plot_stat_map(amyg212, black_bg=False,display_mode='ortho', cut_coords=[-42,-22,-19],
                       draw_cross=False, threshold=3.12)
plotting.show()

# %% [markdown]
# ## Insula163_1 significant cluster

# %%
plt.figure(figsize=(12, 10))
plotting.plot_stat_map(insula163, black_bg=False, display_mode='ortho', cut_coords=[69,-7,-17],
                       draw_cross=False, threshold=3.12)

# %% [markdown]
# ## Insula163_2 significant cluster

# %%
plt.figure(figsize=(12, 10))
plotting.plot_stat_map(insula163, black_bg=False, display_mode='ortho', cut_coords=[-57,-52,17],
                       draw_cross=False, threshold=3.12)

# %% [markdown]
# ## Precuneus152 significant cluster

# %%
plt.figure(figsize=(12, 10))
plotting.plot_stat_map(pcc152, black_bg=False, display_mode='ortho', cut_coords=[9,-73,17],
                       draw_cross=False, threshold=3.12)

# %% [markdown]
# ## Parahippocampus115 significant cluster

# %%
plt.figure(figsize=(12, 10))
plotting.plot_stat_map(parahipp115, black_bg=False, display_mode='ortho', cut_coords=[30,5,-31],
                       draw_cross=False, threshold=3.12)

# %% [markdown]
# ## Parahippocampus116 significant cluster

# %%
plt.figure(figsize=(12, 10))
plotting.plot_stat_map(parahipp116, black_bg=False, display_mode='ortho', cut_coords=[66,-4,26],
                       draw_cross=False, threshold=3.12)

# %% [markdown]
# ## Parahippocampus118 significant cluster

# %%
plt.figure(figsize=(12, 10))
plotting.plot_stat_map(parahipp118, black_bg=False, display_mode='ortho', cut_coords=[-39,-13,-34],
                       draw_cross=False, threshold=3.12)

# %% [markdown]
# ## Precentral64_1 significant cluster

# %%
plt.figure(figsize=(12, 10))
plotting.plot_stat_map(precentral64, black_bg=False, display_mode='ortho', cut_coords=[60,8,32],
                       draw_cross=False, threshold=3.12)

# %% [markdown]
# ## Precentral64_2 significant cluster

# %%
plt.figure(figsize=(12, 10))
plotting.plot_stat_map(precentral64, black_bg=False, display_mode='ortho', cut_coords=[45,-70,20],
                       draw_cross=False, threshold=3.12)
